# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
df=pd.read_csv('/content/data (1).csv')

# %%
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.drop(['Unnamed: 32','id'], axis=1,inplace=True)

# %%
x=df.drop('diagnosis',axis=1)
y=df.diagnosis

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
y = lb.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=50)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
classifier=Sequential()

# %%
classifier.add(Dense(units=9,activation='relu',input_dim=30))
classifier.add(Dense(units=9,activation='relu'))
classifier.add(Dense(units=1,activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 9)                 279
#
#  dense_7 (Dense)             (None, 9)                 90
#
#  dense_8 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 379
# Trainable params: 379
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model = classifier.fit(x_train,y_train,batch_size=100,epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8100 - accuracy: 0.6131
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7475 - accuracy: 0.6156
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6872 - accuracy: 0.6156
# Epoch 4/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6388 - accuracy: 0.6156
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.6156
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5579 - accuracy: 0.6206
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5245 - accuracy: 0.6357
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4945 - accuracy: 0.6583
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4715 - accuracy: 0.6759
# Epoch 10/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4510 - accuracy: 0.6960
# Epoch 11/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4334 - accuracy: 0.7211
# Epoch 12/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4186 - accuracy: 0.7412
# Epoch 13/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4049 - accuracy: 0.7613
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.7965
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3822 - accuracy: 0.8141
# Epoch 16/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3722 - accuracy: 0.8317
# Epoch 17/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3629 - accuracy: 0.8417
# Epoch 18/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3541 - accuracy: 0.8618
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3452 - accuracy: 0.8769
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3364 - accuracy: 0.8844
# Epoch 21/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3276 - accuracy: 0.8970
# Epoch 22/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3190 - accuracy: 0.9095
# Epoch 23/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3108 - accuracy: 0.9196
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3026 - accuracy: 0.9196
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2946 - accuracy: 0.9196
# Epoch 26/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2866 - accuracy: 0.9296
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2787 - accuracy: 0.9322
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2710 - accuracy: 0.9397
# Epoch 29/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2633 - accuracy: 0.9397
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2552 - accuracy: 0.9472
# Epoch 31/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2476 - accuracy: 0.9523
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2403 - accuracy: 0.9523
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2329 - accuracy: 0.9573
# Epoch 34/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2255 - accuracy: 0.9573
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2190 - accuracy: 0.9598
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2123 - accuracy: 0.9598
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.9623
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1996 - accuracy: 0.9598
# Epoch 39/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.9598
# Epoch 40/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1877 - accuracy: 0.9623
# Epoch 41/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1821 - accuracy: 0.9648
# Epoch 42/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1768 - accuracy: 0.9648
# Epoch 43/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1717 - accuracy: 0.9698
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9698
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1621 - accuracy: 0.9724
# Epoch 46/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1575 - accuracy: 0.9698
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1532 - accuracy: 0.9698
# Epoch 48/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1490 - accuracy: 0.9698
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1450 - accuracy: 0.9698
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1410 - accuracy: 0.9698
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1373 - accuracy: 0.9698
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9698
# Epoch 53/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9698
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9698
# Epoch 55/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1238 - accuracy: 0.9698
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1209 - accuracy: 0.9698
# Epoch 57/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9698
# Epoch 58/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1152 - accuracy: 0.9698
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1124 - accuracy: 0.9698
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1097 - accuracy: 0.9698
# Epoch 61/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9698
# Epoch 62/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1049 - accuracy: 0.9724
# Epoch 63/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1024 - accuracy: 0.9724
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1003 - accuracy: 0.9724
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9724
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0962 - accuracy: 0.9724
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9724
# Epoch 68/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9724
# Epoch 69/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0907 - accuracy: 0.9749
# Epoch 70/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0891 - accuracy: 0.9749
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 0.9749
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0859 - accuracy: 0.9774
# Epoch 73/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9774
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9774
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0816 - accuracy: 0.9774
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0802 - accuracy: 0.9774
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0789 - accuracy: 0.9774
# Epoch 78/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0775 - accuracy: 0.9774
# Epoch 79/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9774
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0751 - accuracy: 0.9774
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0739 - accuracy: 0.9799
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9799
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 0.9799
# Epoch 84/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9799
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 0.9799
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9799
# Epoch 87/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0677 - accuracy: 0.9799
# Epoch 88/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0667 - accuracy: 0.9799
# Epoch 89/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0658 - accuracy: 0.9799
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0649 - accuracy: 0.9799
# Epoch 91/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0640 - accuracy: 0.9824
# Epoch 92/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0632 - accuracy: 0.9824
# Epoch 93/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9824
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9824
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9824
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0601 - accuracy: 0.9824
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0593 - accuracy: 0.9824
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9824
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9824
# Epoch 100/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9824

# %%
print(model.history.keys())

plt.plot(model.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])
